# %% [markdown]
# Scan individual parameters in the YYG/C19Pro SEIR model.
# Output plots with dependence of total deaths to these parameters.

# %%
import run_simulation

import numpy as np
import argparse
import sys

import matplotlib
#matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
plt.rcParams.update({'axes.titlesize': 16})
plt.rcParams.update({'axes.labelsize': 14})
plt.rcParams.update({'lines.linewidth' : 2})
plt.rcParams.update({'lines.markersize' : 13})
plt.rcParams.update({'xtick.labelsize' : 13})
plt.rcParams.update({'ytick.labelsize' : 13})



## args needed to run the simulation main
main_args = argparse.Namespace(
    best_params_dir='best_params/latest', best_params_type='mean',
    change_param=None, country='US', quarantine_effectiveness=-1,
    quarantine_perc=0, region='', save_csv_fname='', set_param=None,
    simulation_end_date=None, simulation_start_date=None,
    skip_hospitalizations=False, subregion='', verbose=False
)


###
### Define range of parameters
###

params=['INITIAL_R_0',
        'MORTALITY_RATE',
        'LOCKDOWN_R_0',
        'RATE_OF_INFLECTION'
        ]
param_labels = ['Initial R0',
               'Mortality Rate',
               'Lockdown R0',
               'Rate of Inflection']

par_range={}
par_range['INITIAL_R_0'] = np.arange(0.6,6.,0.2)
par_range['MORTALITY_RATE'] = np.arange(0.005,0.05,0.005)
par_range['LOCKDOWN_R_0']=np.arange(0.5,1.5,0.1)
par_range['RATE_OF_INFLECTION']=np.arange(0.15, 0.7, 0.1)

## baseline parameters
default={}
default['INITIAL_R_0'] = 2.2637755302375644
default['MORTALITY_RATE'] = 0.01
default['LOCKDOWN_R_0']=0.9038440070216232
default['RATE_OF_INFLECTION']=0.35245146707754205
default['REOPEN_R']=1.2681889965435804
default['POST_REOPEN_EQUILIBRIUM_R']=1.0073471671122585

## best-case parameters
best={}
best['INITIAL_R_0'] = 1.8
best['MORTALITY_RATE'] = 0.007
best['LOCKDOWN_R_0']=0.7
best['RATE_OF_INFLECTION']=0.5

## worst-case parameters
worst={}
worst['INITIAL_R_0'] = 4.
worst['MORTALITY_RATE'] = 0.03
worst['LOCKDOWN_R_0']=1.2
worst['RATE_OF_INFLECTION']=0.25

set_params=[]
for param in params:
    set_params += [(param, default[param])]
main_args.set_param = set_params
default['total_deaths'] = run_simulation.main(main_args)


fig,axs=plt.subplots(2,2, figsize=(15,12))
for i,param in enumerate(params):
    ## Scan each parameter
    if i<2:
        row,col=0,i
    else:
        row,col=1,i-2

    x,y=[],[]
    for value in par_range[param]:
        x+=[value]
        main_args.set_param=[(param, value)]
        y+=[ run_simulation.main(main_args) ]
    axs[row,col].plot(x,y, label='Scan of %s'%param_labels[i])
    axs[row,col].scatter(default[param], default['total_deaths'], color='blue', label='baseline simulation')
    main_args.set_param=[(param, best[param])]
    best['total_deaths'] = run_simulation.main(main_args)
    main_args.set_param=[(param, worst[param])]
    worst['total_deaths'] = run_simulation.main(main_args)
    axs[row,col].scatter(best[param], best['total_deaths'], color='g', label='best-case scenario')
    axs[row,col].scatter(worst[param], worst['total_deaths'], color='r', label='worst-case scenario')
    axs[row,col].set_title(param_labels[i])
    axs[row,col].set_xlabel(param_labels[i])
    axs[row,col].set_ylabel('Total deaths')
    axs[row,col].legend(fontsize=15)
    main_args.set_param=[(param, default[param])]

plt.tight_layout()
plt.show()
# Out:
# Loading params file: best_params/latest/US_ALL.json
#
#
#  Best parameters:
#  {'country': 'US', 'current_r': 1.047559981113069, 'date': '2020-10-04', 'first_date': '2020-02-05', 'fixed_params': [['PROJECTION_END_DATE', '2020-11-01'], ['INCUBATION_DAYS', 2], ['INFECTIOUS_DAYS_ARR', [0.5, 1.0, 2.0, 3.0, 2.0, 1.0, 0.5]], ['DEATHS_DAYS_ARR', [1, 2, 3, 4, 4, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2]], ['DAYS_UNTIL_HOSPITALIZATION', 12], ['HOSPITALIZATION_RATE', 0.02], ['DAYS_IN_HOSPITAL', 11], ['DAYS_BEFORE_DEATH', 22], ['DEATH_REPORTING_LAG_ARR', [0.0, 16.5, 13.200000000000001, 10.560000000000002, 8.448000000000002, 6.758400000000001, 5.406720000000002, 4.325376000000001, 3.460300800000001, 2.7682406400000015, 2.214592512000001, 2.103862886400001, 1.9986697420800008, 1.8987362549760005, 1.8037994422272006, 1.7136094701158404, 1.6279289966100483, 1.5465325467795457, 1.4692059194405684, 1.39574562346854, 1.3259583422951131, 1.2596604251803571, 1.1966774039213395, 1.1368435337252722, 1.0800013570390086, 1.026001289187058, 0.9747012247277052, 0.9259661634913199, 0.8796678553167538, 0.8356844625509161, 0.7939002394233703]], ['MEAN_ERROR_DECAY', 1], ['MEAN_ERROR_DECAY_LOWER', 0.95], ['MIN_ALPHA_RATIO', 0.1], ['LOSS_FUNCTION_NAME', 'nth_power_diff'], ['NTH_POWER_ERROR', 2], ['MODEL_WEIGHT_ERROR_POWER', 1.5], ['PERC_PARAMS_PER_INFECTION_DAY', 0.075], ['PERC_PARAMS_PER_INFECTION_DAY_US_EUROPE', 0.075], ['MIN_PARAMS_PER_INFLECTION_DAY', 20], ['DAYS_UNTIL_RECOVERY', 15], ['IMMUNITY_MULTIPLIER', 0.5], ['IMMUNITY_MULTIPLIER_US_SUBREGION', 0.3], ['PREV_WEEK_RATIO_SENSITIVITY', 0.75], ['DAYS_UNTIL_LOCKDOWN_FATIGUE', 28], ['MORTALITY_MULTIPLIER', 0.995], ['MORTALITY_MULTIPLIER_US_REOPEN', 0.975], ['MIN_MORTALITY_MULTIPLIER', 0.3], ['MIN_IFR', 0.002], ['DAYS_WITH_IMPORTS', 100], ['USE_UNDETECTED_DEATHS_RATIO', True], ['DEFAULT_REOPEN_SHIFT_DAYS', 15], ['DATE_PARAMS', ['INFLECTION_DAY', 'REOPEN_DATE']], ['RANDOMIZED_PARAMS', ['POST_REOPEN_EQUILIBRIUM_R', 'FALL_R_MULTIPLIER']], ['POTENTIAL_RANDOMIZE_PARAMS', ['RATE_OF_INFLECTION', 'DAILY_IMPORTS']]], 'mean_params': [['INITIAL_R_0', 2.2637755302375644], ['LOCKDOWN_R_0', 0.9038440070216232], ['INFLECTION_DAY', '2020-03-15'], ['RATE_OF_INFLECTION', 0.35245146707754205], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1089.8993483065829], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-10'], ['REOPEN_SHIFT_DAYS', -0.1425555065958532], ['REOPEN_R', 1.2681889965435804], ['REOPEN_INFLECTION', 0.32847835689143956], ['POST_REOPEN_EQUILIBRIUM_R', 1.0073471671122585], ['FALL_R_MULTIPLIER', 1.0020627766084023]], 'median_params': [['INITIAL_R_0', 2.2], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-16'], ['RATE_OF_INFLECTION', 0.3493758807155695], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1049.0], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-13'], ['REOPEN_SHIFT_DAYS', 0.0], ['REOPEN_R', 1.2500000000000002], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 1.0097900527702364], ['FALL_R_MULTIPLIER', 1.002108328865356]], 'num_params': 9072, 'num_params_filt': 684, 'population': 331814684, 'projection_end_date': '2020-11-01', 'region': 'ALL', 'subregion': '', 'top10_params': [['INITIAL_R_0', 2.3200000000000007], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-14'], ['RATE_OF_INFLECTION', 0.35734814824111294], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1203.8], ['MORTALITY_RATE', 0.010000000000000002], ['REOPEN_DATE', '2020-05-06'], ['REOPEN_SHIFT_DAYS', 2.5], ['REOPEN_R', 1.2850000000000001], ['REOPEN_INFLECTION', 0.33499999999999996], ['POST_REOPEN_EQUILIBRIUM_R', 1.0030626817207222], ['FALL_R_MULTIPLIER', 1.002202543680243]], 'top_params': [['INITIAL_R_0', 2.4000000000000004], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-13'], ['RATE_OF_INFLECTION', 0.40837680600799475], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1197], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-01'], ['REOPEN_SHIFT_DAYS', 5], ['REOPEN_R', 1.3000000000000003], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 0.9874301179968146], ['FALL_R_MULTIPLIER', 1.002399465808581]]}
#
#
# ---------------------------------------
# Overwriting params from command line...
# Setting INITIAL_R_0 to: 2.2637755302375644
# Setting MORTALITY_RATE to: 0.01
# Setting LOCKDOWN_R_0 to: 0.9038440070216232
# Setting RATE_OF_INFLECTION to: 0.35245146707754205
# -------------------------------------
# End of simulation       : 2020-11-01
# Total infections        : 61,462,743
# Peak hospital beds used : 79,855
# Total deaths            : 224,263
# Loading params file: best_params/latest/US_ALL.json
#
#
#  Best parameters:
#  {'country': 'US', 'current_r': 1.047559981113069, 'date': '2020-10-04', 'first_date': '2020-02-05', 'fixed_params': [['PROJECTION_END_DATE', '2020-11-01'], ['INCUBATION_DAYS', 2], ['INFECTIOUS_DAYS_ARR', [0.5, 1.0, 2.0, 3.0, 2.0, 1.0, 0.5]], ['DEATHS_DAYS_ARR', [1, 2, 3, 4, 4, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2]], ['DAYS_UNTIL_HOSPITALIZATION', 12], ['HOSPITALIZATION_RATE', 0.02], ['DAYS_IN_HOSPITAL', 11], ['DAYS_BEFORE_DEATH', 22], ['DEATH_REPORTING_LAG_ARR', [0.0, 16.5, 13.200000000000001, 10.560000000000002, 8.448000000000002, 6.758400000000001, 5.406720000000002, 4.325376000000001, 3.460300800000001, 2.7682406400000015, 2.214592512000001, 2.103862886400001, 1.9986697420800008, 1.8987362549760005, 1.8037994422272006, 1.7136094701158404, 1.6279289966100483, 1.5465325467795457, 1.4692059194405684, 1.39574562346854, 1.3259583422951131, 1.2596604251803571, 1.1966774039213395, 1.1368435337252722, 1.0800013570390086, 1.026001289187058, 0.9747012247277052, 0.9259661634913199, 0.8796678553167538, 0.8356844625509161, 0.7939002394233703]], ['MEAN_ERROR_DECAY', 1], ['MEAN_ERROR_DECAY_LOWER', 0.95], ['MIN_ALPHA_RATIO', 0.1], ['LOSS_FUNCTION_NAME', 'nth_power_diff'], ['NTH_POWER_ERROR', 2], ['MODEL_WEIGHT_ERROR_POWER', 1.5], ['PERC_PARAMS_PER_INFECTION_DAY', 0.075], ['PERC_PARAMS_PER_INFECTION_DAY_US_EUROPE', 0.075], ['MIN_PARAMS_PER_INFLECTION_DAY', 20], ['DAYS_UNTIL_RECOVERY', 15], ['IMMUNITY_MULTIPLIER', 0.5], ['IMMUNITY_MULTIPLIER_US_SUBREGION', 0.3], ['PREV_WEEK_RATIO_SENSITIVITY', 0.75], ['DAYS_UNTIL_LOCKDOWN_FATIGUE', 28], ['MORTALITY_MULTIPLIER', 0.995], ['MORTALITY_MULTIPLIER_US_REOPEN', 0.975], ['MIN_MORTALITY_MULTIPLIER', 0.3], ['MIN_IFR', 0.002], ['DAYS_WITH_IMPORTS', 100], ['USE_UNDETECTED_DEATHS_RATIO', True], ['DEFAULT_REOPEN_SHIFT_DAYS', 15], ['DATE_PARAMS', ['INFLECTION_DAY', 'REOPEN_DATE']], ['RANDOMIZED_PARAMS', ['POST_REOPEN_EQUILIBRIUM_R', 'FALL_R_MULTIPLIER']], ['POTENTIAL_RANDOMIZE_PARAMS', ['RATE_OF_INFLECTION', 'DAILY_IMPORTS']]], 'mean_params': [['INITIAL_R_0', 2.2637755302375644], ['LOCKDOWN_R_0', 0.9038440070216232], ['INFLECTION_DAY', '2020-03-15'], ['RATE_OF_INFLECTION', 0.35245146707754205], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1089.8993483065829], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-10'], ['REOPEN_SHIFT_DAYS', -0.1425555065958532], ['REOPEN_R', 1.2681889965435804], ['REOPEN_INFLECTION', 0.32847835689143956], ['POST_REOPEN_EQUILIBRIUM_R', 1.0073471671122585], ['FALL_R_MULTIPLIER', 1.0020627766084023]], 'median_params': [['INITIAL_R_0', 2.2], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-16'], ['RATE_OF_INFLECTION', 0.3493758807155695], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1049.0], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-13'], ['REOPEN_SHIFT_DAYS', 0.0], ['REOPEN_R', 1.2500000000000002], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 1.0097900527702364], ['FALL_R_MULTIPLIER', 1.002108328865356]], 'num_params': 9072, 'num_params_filt': 684, 'population': 331814684, 'projection_end_date': '2020-11-01', 'region': 'ALL', 'subregion': '', 'top10_params': [['INITIAL_R_0', 2.3200000000000007], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-14'], ['RATE_OF_INFLECTION', 0.35734814824111294], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1203.8], ['MORTALITY_RATE', 0.010000000000000002], ['REOPEN_DATE', '2020-05-06'], ['REOPEN_SHIFT_DAYS', 2.5], ['REOPEN_R', 1.2850000000000001], ['REOPEN_INFLECTION', 0.33499999999999996], ['POST_REOPEN_EQUILIBRIUM_R', 1.0030626817207222], ['FALL_R_MULTIPLIER', 1.002202543680243]], 'top_params': [['INITIAL_R_0', 2.4000000000000004], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-13'], ['RATE_OF_INFLECTION', 0.40837680600799475], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1197], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-01'], ['REOPEN_SHIFT_DAYS', 5], ['REOPEN_R', 1.3000000000000003], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 0.9874301179968146], ['FALL_R_MULTIPLIER', 1.002399465808581]]}
#
#
# ---------------------------------------
# Overwriting params from command line...
# Setting INITIAL_R_0 to: 0.6
# -------------------------------------
# End of simulation       : 2020-11-01
# Total infections        : 3,593,787
# Peak hospital beds used : 9,167
# Total deaths            : 7,663
# Loading params file: best_params/latest/US_ALL.json
#
#
#  Best parameters:
#  {'country': 'US', 'current_r': 1.047559981113069, 'date': '2020-10-04', 'first_date': '2020-02-05', 'fixed_params': [['PROJECTION_END_DATE', '2020-11-01'], ['INCUBATION_DAYS', 2], ['INFECTIOUS_DAYS_ARR', [0.5, 1.0, 2.0, 3.0, 2.0, 1.0, 0.5]], ['DEATHS_DAYS_ARR', [1, 2, 3, 4, 4, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2]], ['DAYS_UNTIL_HOSPITALIZATION', 12], ['HOSPITALIZATION_RATE', 0.02], ['DAYS_IN_HOSPITAL', 11], ['DAYS_BEFORE_DEATH', 22], ['DEATH_REPORTING_LAG_ARR', [0.0, 16.5, 13.200000000000001, 10.560000000000002, 8.448000000000002, 6.758400000000001, 5.406720000000002, 4.325376000000001, 3.460300800000001, 2.7682406400000015, 2.214592512000001, 2.103862886400001, 1.9986697420800008, 1.8987362549760005, 1.8037994422272006, 1.7136094701158404, 1.6279289966100483, 1.5465325467795457, 1.4692059194405684, 1.39574562346854, 1.3259583422951131, 1.2596604251803571, 1.1966774039213395, 1.1368435337252722, 1.0800013570390086, 1.026001289187058, 0.9747012247277052, 0.9259661634913199, 0.8796678553167538, 0.8356844625509161, 0.7939002394233703]], ['MEAN_ERROR_DECAY', 1], ['MEAN_ERROR_DECAY_LOWER', 0.95], ['MIN_ALPHA_RATIO', 0.1], ['LOSS_FUNCTION_NAME', 'nth_power_diff'], ['NTH_POWER_ERROR', 2], ['MODEL_WEIGHT_ERROR_POWER', 1.5], ['PERC_PARAMS_PER_INFECTION_DAY', 0.075], ['PERC_PARAMS_PER_INFECTION_DAY_US_EUROPE', 0.075], ['MIN_PARAMS_PER_INFLECTION_DAY', 20], ['DAYS_UNTIL_RECOVERY', 15], ['IMMUNITY_MULTIPLIER', 0.5], ['IMMUNITY_MULTIPLIER_US_SUBREGION', 0.3], ['PREV_WEEK_RATIO_SENSITIVITY', 0.75], ['DAYS_UNTIL_LOCKDOWN_FATIGUE', 28], ['MORTALITY_MULTIPLIER', 0.995], ['MORTALITY_MULTIPLIER_US_REOPEN', 0.975], ['MIN_MORTALITY_MULTIPLIER', 0.3], ['MIN_IFR', 0.002], ['DAYS_WITH_IMPORTS', 100], ['USE_UNDETECTED_DEATHS_RATIO', True], ['DEFAULT_REOPEN_SHIFT_DAYS', 15], ['DATE_PARAMS', ['INFLECTION_DAY', 'REOPEN_DATE']], ['RANDOMIZED_PARAMS', ['POST_REOPEN_EQUILIBRIUM_R', 'FALL_R_MULTIPLIER']], ['POTENTIAL_RANDOMIZE_PARAMS', ['RATE_OF_INFLECTION', 'DAILY_IMPORTS']]], 'mean_params': [['INITIAL_R_0', 2.2637755302375644], ['LOCKDOWN_R_0', 0.9038440070216232], ['INFLECTION_DAY', '2020-03-15'], ['RATE_OF_INFLECTION', 0.35245146707754205], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1089.8993483065829], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-10'], ['REOPEN_SHIFT_DAYS', -0.1425555065958532], ['REOPEN_R', 1.2681889965435804], ['REOPEN_INFLECTION', 0.32847835689143956], ['POST_REOPEN_EQUILIBRIUM_R', 1.0073471671122585], ['FALL_R_MULTIPLIER', 1.0020627766084023]], 'median_params': [['INITIAL_R_0', 2.2], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-16'], ['RATE_OF_INFLECTION', 0.3493758807155695], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1049.0], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-13'], ['REOPEN_SHIFT_DAYS', 0.0], ['REOPEN_R', 1.2500000000000002], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 1.0097900527702364], ['FALL_R_MULTIPLIER', 1.002108328865356]], 'num_params': 9072, 'num_params_filt': 684, 'population': 331814684, 'projection_end_date': '2020-11-01', 'region': 'ALL', 'subregion': '', 'top10_params': [['INITIAL_R_0', 2.3200000000000007], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-14'], ['RATE_OF_INFLECTION', 0.35734814824111294], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1203.8], ['MORTALITY_RATE', 0.010000000000000002], ['REOPEN_DATE', '2020-05-06'], ['REOPEN_SHIFT_DAYS', 2.5], ['REOPEN_R', 1.2850000000000001], ['REOPEN_INFLECTION', 0.33499999999999996], ['POST_REOPEN_EQUILIBRIUM_R', 1.0030626817207222], ['FALL_R_MULTIPLIER', 1.002202543680243]], 'top_params': [['INITIAL_R_0', 2.4000000000000004], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-13'], ['RATE_OF_INFLECTION', 0.40837680600799475], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1197], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-01'], ['REOPEN_SHIFT_DAYS', 5], ['REOPEN_R', 1.3000000000000003], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 0.9874301179968146], ['FALL_R_MULTIPLIER', 1.002399465808581]]}
#
#
# ---------------------------------------
# Overwriting params from command line...
# Setting INITIAL_R_0 to: 0.8
# -------------------------------------
# End of simulation       : 2020-11-01
# Total infections        : 4,171,718
# Peak hospital beds used : 10,513
# Total deaths            : 9,116
# Loading params file: best_params/latest/US_ALL.json
#
#
#  Best parameters:
#  {'country': 'US', 'current_r': 1.047559981113069, 'date': '2020-10-04', 'first_date': '2020-02-05', 'fixed_params': [['PROJECTION_END_DATE', '2020-11-01'], ['INCUBATION_DAYS', 2], ['INFECTIOUS_DAYS_ARR', [0.5, 1.0, 2.0, 3.0, 2.0, 1.0, 0.5]], ['DEATHS_DAYS_ARR', [1, 2, 3, 4, 4, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2]], ['DAYS_UNTIL_HOSPITALIZATION', 12], ['HOSPITALIZATION_RATE', 0.02], ['DAYS_IN_HOSPITAL', 11], ['DAYS_BEFORE_DEATH', 22], ['DEATH_REPORTING_LAG_ARR', [0.0, 16.5, 13.200000000000001, 10.560000000000002, 8.448000000000002, 6.758400000000001, 5.406720000000002, 4.325376000000001, 3.460300800000001, 2.7682406400000015, 2.214592512000001, 2.103862886400001, 1.9986697420800008, 1.8987362549760005, 1.8037994422272006, 1.7136094701158404, 1.6279289966100483, 1.5465325467795457, 1.4692059194405684, 1.39574562346854, 1.3259583422951131, 1.2596604251803571, 1.1966774039213395, 1.1368435337252722, 1.0800013570390086, 1.026001289187058, 0.9747012247277052, 0.9259661634913199, 0.8796678553167538, 0.8356844625509161, 0.7939002394233703]], ['MEAN_ERROR_DECAY', 1], ['MEAN_ERROR_DECAY_LOWER', 0.95], ['MIN_ALPHA_RATIO', 0.1], ['LOSS_FUNCTION_NAME', 'nth_power_diff'], ['NTH_POWER_ERROR', 2], ['MODEL_WEIGHT_ERROR_POWER', 1.5], ['PERC_PARAMS_PER_INFECTION_DAY', 0.075], ['PERC_PARAMS_PER_INFECTION_DAY_US_EUROPE', 0.075], ['MIN_PARAMS_PER_INFLECTION_DAY', 20], ['DAYS_UNTIL_RECOVERY', 15], ['IMMUNITY_MULTIPLIER', 0.5], ['IMMUNITY_MULTIPLIER_US_SUBREGION', 0.3], ['PREV_WEEK_RATIO_SENSITIVITY', 0.75], ['DAYS_UNTIL_LOCKDOWN_FATIGUE', 28], ['MORTALITY_MULTIPLIER', 0.995], ['MORTALITY_MULTIPLIER_US_REOPEN', 0.975], ['MIN_MORTALITY_MULTIPLIER', 0.3], ['MIN_IFR', 0.002], ['DAYS_WITH_IMPORTS', 100], ['USE_UNDETECTED_DEATHS_RATIO', True], ['DEFAULT_REOPEN_SHIFT_DAYS', 15], ['DATE_PARAMS', ['INFLECTION_DAY', 'REOPEN_DATE']], ['RANDOMIZED_PARAMS', ['POST_REOPEN_EQUILIBRIUM_R', 'FALL_R_MULTIPLIER']], ['POTENTIAL_RANDOMIZE_PARAMS', ['RATE_OF_INFLECTION', 'DAILY_IMPORTS']]], 'mean_params': [['INITIAL_R_0', 2.2637755302375644], ['LOCKDOWN_R_0', 0.9038440070216232], ['INFLECTION_DAY', '2020-03-15'], ['RATE_OF_INFLECTION', 0.35245146707754205], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1089.8993483065829], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-10'], ['REOPEN_SHIFT_DAYS', -0.1425555065958532], ['REOPEN_R', 1.2681889965435804], ['REOPEN_INFLECTION', 0.32847835689143956], ['POST_REOPEN_EQUILIBRIUM_R', 1.0073471671122585], ['FALL_R_MULTIPLIER', 1.0020627766084023]], 'median_params': [['INITIAL_R_0', 2.2], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-16'], ['RATE_OF_INFLECTION', 0.3493758807155695], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1049.0], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-13'], ['REOPEN_SHIFT_DAYS', 0.0], ['REOPEN_R', 1.2500000000000002], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 1.0097900527702364], ['FALL_R_MULTIPLIER', 1.002108328865356]], 'num_params': 9072, 'num_params_filt': 684, 'population': 331814684, 'projection_end_date': '2020-11-01', 'region': 'ALL', 'subregion': '', 'top10_params': [['INITIAL_R_0', 2.3200000000000007], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-14'], ['RATE_OF_INFLECTION', 0.35734814824111294], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1203.8], ['MORTALITY_RATE', 0.010000000000000002], ['REOPEN_DATE', '2020-05-06'], ['REOPEN_SHIFT_DAYS', 2.5], ['REOPEN_R', 1.2850000000000001], ['REOPEN_INFLECTION', 0.33499999999999996], ['POST_REOPEN_EQUILIBRIUM_R', 1.0030626817207222], ['FALL_R_MULTIPLIER', 1.002202543680243]], 'top_params': [['INITIAL_R_0', 2.4000000000000004], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-13'], ['RATE_OF_INFLECTION', 0.40837680600799475], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1197], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-01'], ['REOPEN_SHIFT_DAYS', 5], ['REOPEN_R', 1.3000000000000003], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 0.9874301179968146], ['FALL_R_MULTIPLIER', 1.002399465808581]]}
#
#
# ---------------------------------------
# Overwriting params from command line...
# Setting INITIAL_R_0 to: 1.0
# -------------------------------------
# End of simulation       : 2020-11-01
# Total infections        : 5,366,001
# Peak hospital beds used : 13,294
# Total deaths            : 12,098
# Loading params file: best_params/latest/US_ALL.json
#
#
#  Best parameters:
#  {'country': 'US', 'current_r': 1.047559981113069, 'date': '2020-10-04', 'first_date': '2020-02-05', 'fixed_params': [['PROJECTION_END_DATE', '2020-11-01'], ['INCUBATION_DAYS', 2], ['INFECTIOUS_DAYS_ARR', [0.5, 1.0, 2.0, 3.0, 2.0, 1.0, 0.5]], ['DEATHS_DAYS_ARR', [1, 2, 3, 4, 4, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2]], ['DAYS_UNTIL_HOSPITALIZATION', 12], ['HOSPITALIZATION_RATE', 0.02], ['DAYS_IN_HOSPITAL', 11], ['DAYS_BEFORE_DEATH', 22], ['DEATH_REPORTING_LAG_ARR', [0.0, 16.5, 13.200000000000001, 10.560000000000002, 8.448000000000002, 6.758400000000001, 5.406720000000002, 4.325376000000001, 3.460300800000001, 2.7682406400000015, 2.214592512000001, 2.103862886400001, 1.9986697420800008, 1.8987362549760005, 1.8037994422272006, 1.7136094701158404, 1.6279289966100483, 1.5465325467795457, 1.4692059194405684, 1.39574562346854, 1.3259583422951131, 1.2596604251803571, 1.1966774039213395, 1.1368435337252722, 1.0800013570390086, 1.026001289187058, 0.9747012247277052, 0.9259661634913199, 0.8796678553167538, 0.8356844625509161, 0.7939002394233703]], ['MEAN_ERROR_DECAY', 1], ['MEAN_ERROR_DECAY_LOWER', 0.95], ['MIN_ALPHA_RATIO', 0.1], ['LOSS_FUNCTION_NAME', 'nth_power_diff'], ['NTH_POWER_ERROR', 2], ['MODEL_WEIGHT_ERROR_POWER', 1.5], ['PERC_PARAMS_PER_INFECTION_DAY', 0.075], ['PERC_PARAMS_PER_INFECTION_DAY_US_EUROPE', 0.075], ['MIN_PARAMS_PER_INFLECTION_DAY', 20], ['DAYS_UNTIL_RECOVERY', 15], ['IMMUNITY_MULTIPLIER', 0.5], ['IMMUNITY_MULTIPLIER_US_SUBREGION', 0.3], ['PREV_WEEK_RATIO_SENSITIVITY', 0.75], ['DAYS_UNTIL_LOCKDOWN_FATIGUE', 28], ['MORTALITY_MULTIPLIER', 0.995], ['MORTALITY_MULTIPLIER_US_REOPEN', 0.975], ['MIN_MORTALITY_MULTIPLIER', 0.3], ['MIN_IFR', 0.002], ['DAYS_WITH_IMPORTS', 100], ['USE_UNDETECTED_DEATHS_RATIO', True], ['DEFAULT_REOPEN_SHIFT_DAYS', 15], ['DATE_PARAMS', ['INFLECTION_DAY', 'REOPEN_DATE']], ['RANDOMIZED_PARAMS', ['POST_REOPEN_EQUILIBRIUM_R', 'FALL_R_MULTIPLIER']], ['POTENTIAL_RANDOMIZE_PARAMS', ['RATE_OF_INFLECTION', 'DAILY_IMPORTS']]], 'mean_params': [['INITIAL_R_0', 2.2637755302375644], ['LOCKDOWN_R_0', 0.9038440070216232], ['INFLECTION_DAY', '2020-03-15'], ['RATE_OF_INFLECTION', 0.35245146707754205], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1089.8993483065829], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-10'], ['REOPEN_SHIFT_DAYS', -0.1425555065958532], ['REOPEN_R', 1.2681889965435804], ['REOPEN_INFLECTION', 0.32847835689143956], ['POST_REOPEN_EQUILIBRIUM_R', 1.0073471671122585], ['FALL_R_MULTIPLIER', 1.0020627766084023]], 'median_params': [['INITIAL_R_0', 2.2], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-16'], ['RATE_OF_INFLECTION', 0.3493758807155695], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1049.0], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-13'], ['REOPEN_SHIFT_DAYS', 0.0], ['REOPEN_R', 1.2500000000000002], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 1.0097900527702364], ['FALL_R_MULTIPLIER', 1.002108328865356]], 'num_params': 9072, 'num_params_filt': 684, 'population': 331814684, 'projection_end_date': '2020-11-01', 'region': 'ALL', 'subregion': '', 'top10_params': [['INITIAL_R_0', 2.3200000000000007], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-14'], ['RATE_OF_INFLECTION', 0.35734814824111294], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1203.8], ['MORTALITY_RATE', 0.010000000000000002], ['REOPEN_DATE', '2020-05-06'], ['REOPEN_SHIFT_DAYS', 2.5], ['REOPEN_R', 1.2850000000000001], ['REOPEN_INFLECTION', 0.33499999999999996], ['POST_REOPEN_EQUILIBRIUM_R', 1.0030626817207222], ['FALL_R_MULTIPLIER', 1.002202543680243]], 'top_params': [['INITIAL_R_0', 2.4000000000000004], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-13'], ['RATE_OF_INFLECTION', 0.40837680600799475], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1197], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-01'], ['REOPEN_SHIFT_DAYS', 5], ['REOPEN_R', 1.3000000000000003], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 0.9874301179968146], ['FALL_R_MULTIPLIER', 1.002399465808581]]}
#
#
# ---------------------------------------
# Overwriting params from command line...
# Setting INITIAL_R_0 to: 1.2000000000000002
# -------------------------------------
# End of simulation       : 2020-11-01
# Total infections        : 7,765,124
# Peak hospital beds used : 18,796
# Total deaths            : 18,127
# Loading params file: best_params/latest/US_ALL.json
#
#
#  Best parameters:
#  {'country': 'US', 'current_r': 1.047559981113069, 'date': '2020-10-04', 'first_date': '2020-02-05', 'fixed_params': [['PROJECTION_END_DATE', '2020-11-01'], ['INCUBATION_DAYS', 2], ['INFECTIOUS_DAYS_ARR', [0.5, 1.0, 2.0, 3.0, 2.0, 1.0, 0.5]], ['DEATHS_DAYS_ARR', [1, 2, 3, 4, 4, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2]], ['DAYS_UNTIL_HOSPITALIZATION', 12], ['HOSPITALIZATION_RATE', 0.02], ['DAYS_IN_HOSPITAL', 11], ['DAYS_BEFORE_DEATH', 22], ['DEATH_REPORTING_LAG_ARR', [0.0, 16.5, 13.200000000000001, 10.560000000000002, 8.448000000000002, 6.758400000000001, 5.406720000000002, 4.325376000000001, 3.460300800000001, 2.7682406400000015, 2.214592512000001, 2.103862886400001, 1.9986697420800008, 1.8987362549760005, 1.8037994422272006, 1.7136094701158404, 1.6279289966100483, 1.5465325467795457, 1.4692059194405684, 1.39574562346854, 1.3259583422951131, 1.2596604251803571, 1.1966774039213395, 1.1368435337252722, 1.0800013570390086, 1.026001289187058, 0.9747012247277052, 0.9259661634913199, 0.8796678553167538, 0.8356844625509161, 0.7939002394233703]], ['MEAN_ERROR_DECAY', 1], ['MEAN_ERROR_DECAY_LOWER', 0.95], ['MIN_ALPHA_RATIO', 0.1], ['LOSS_FUNCTION_NAME', 'nth_power_diff'], ['NTH_POWER_ERROR', 2], ['MODEL_WEIGHT_ERROR_POWER', 1.5], ['PERC_PARAMS_PER_INFECTION_DAY', 0.075], ['PERC_PARAMS_PER_INFECTION_DAY_US_EUROPE', 0.075], ['MIN_PARAMS_PER_INFLECTION_DAY', 20], ['DAYS_UNTIL_RECOVERY', 15], ['IMMUNITY_MULTIPLIER', 0.5], ['IMMUNITY_MULTIPLIER_US_SUBREGION', 0.3], ['PREV_WEEK_RATIO_SENSITIVITY', 0.75], ['DAYS_UNTIL_LOCKDOWN_FATIGUE', 28], ['MORTALITY_MULTIPLIER', 0.995], ['MORTALITY_MULTIPLIER_US_REOPEN', 0.975], ['MIN_MORTALITY_MULTIPLIER', 0.3], ['MIN_IFR', 0.002], ['DAYS_WITH_IMPORTS', 100], ['USE_UNDETECTED_DEATHS_RATIO', True], ['DEFAULT_REOPEN_SHIFT_DAYS', 15], ['DATE_PARAMS', ['INFLECTION_DAY', 'REOPEN_DATE']], ['RANDOMIZED_PARAMS', ['POST_REOPEN_EQUILIBRIUM_R', 'FALL_R_MULTIPLIER']], ['POTENTIAL_RANDOMIZE_PARAMS', ['RATE_OF_INFLECTION', 'DAILY_IMPORTS']]], 'mean_params': [['INITIAL_R_0', 2.2637755302375644], ['LOCKDOWN_R_0', 0.9038440070216232], ['INFLECTION_DAY', '2020-03-15'], ['RATE_OF_INFLECTION', 0.35245146707754205], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1089.8993483065829], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-10'], ['REOPEN_SHIFT_DAYS', -0.1425555065958532], ['REOPEN_R', 1.2681889965435804], ['REOPEN_INFLECTION', 0.32847835689143956], ['POST_REOPEN_EQUILIBRIUM_R', 1.0073471671122585], ['FALL_R_MULTIPLIER', 1.0020627766084023]], 'median_params': [['INITIAL_R_0', 2.2], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-16'], ['RATE_OF_INFLECTION', 0.3493758807155695], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1049.0], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-13'], ['REOPEN_SHIFT_DAYS', 0.0], ['REOPEN_R', 1.2500000000000002], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 1.0097900527702364], ['FALL_R_MULTIPLIER', 1.002108328865356]], 'num_params': 9072, 'num_params_filt': 684, 'population': 331814684, 'projection_end_date': '2020-11-01', 'region': 'ALL', 'subregion': '', 'top10_params': [['INITIAL_R_0', 2.3200000000000007], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-14'], ['RATE_OF_INFLECTION', 0.35734814824111294], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1203.8], ['MORTALITY_RATE', 0.010000000000000002], ['REOPEN_DATE', '2020-05-06'], ['REOPEN_SHIFT_DAYS', 2.5], ['REOPEN_R', 1.2850000000000001], ['REOPEN_INFLECTION', 0.33499999999999996], ['POST_REOPEN_EQUILIBRIUM_R', 1.0030626817207222], ['FALL_R_MULTIPLIER', 1.002202543680243]], 'top_params': [['INITIAL_R_0', 2.4000000000000004], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-13'], ['RATE_OF_INFLECTION', 0.40837680600799475], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1197], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-01'], ['REOPEN_SHIFT_DAYS', 5], ['REOPEN_R', 1.3000000000000003], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 0.9874301179968146], ['FALL_R_MULTIPLIER', 1.002399465808581]]}
#
#
# ---------------------------------------
# Overwriting params from command line...
# Setting INITIAL_R_0 to: 1.4000000000000004
# -------------------------------------
# End of simulation       : 2020-11-01
# Total infections        : 12,253,150
# Peak hospital beds used : 28,656
# Total deaths            : 29,740
# Loading params file: best_params/latest/US_ALL.json
#
#
#  Best parameters:
#  {'country': 'US', 'current_r': 1.047559981113069, 'date': '2020-10-04', 'first_date': '2020-02-05', 'fixed_params': [['PROJECTION_END_DATE', '2020-11-01'], ['INCUBATION_DAYS', 2], ['INFECTIOUS_DAYS_ARR', [0.5, 1.0, 2.0, 3.0, 2.0, 1.0, 0.5]], ['DEATHS_DAYS_ARR', [1, 2, 3, 4, 4, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2]], ['DAYS_UNTIL_HOSPITALIZATION', 12], ['HOSPITALIZATION_RATE', 0.02], ['DAYS_IN_HOSPITAL', 11], ['DAYS_BEFORE_DEATH', 22], ['DEATH_REPORTING_LAG_ARR', [0.0, 16.5, 13.200000000000001, 10.560000000000002, 8.448000000000002, 6.758400000000001, 5.406720000000002, 4.325376000000001, 3.460300800000001, 2.7682406400000015, 2.214592512000001, 2.103862886400001, 1.9986697420800008, 1.8987362549760005, 1.8037994422272006, 1.7136094701158404, 1.6279289966100483, 1.5465325467795457, 1.4692059194405684, 1.39574562346854, 1.3259583422951131, 1.2596604251803571, 1.1966774039213395, 1.1368435337252722, 1.0800013570390086, 1.026001289187058, 0.9747012247277052, 0.9259661634913199, 0.8796678553167538, 0.8356844625509161, 0.7939002394233703]], ['MEAN_ERROR_DECAY', 1], ['MEAN_ERROR_DECAY_LOWER', 0.95], ['MIN_ALPHA_RATIO', 0.1], ['LOSS_FUNCTION_NAME', 'nth_power_diff'], ['NTH_POWER_ERROR', 2], ['MODEL_WEIGHT_ERROR_POWER', 1.5], ['PERC_PARAMS_PER_INFECTION_DAY', 0.075], ['PERC_PARAMS_PER_INFECTION_DAY_US_EUROPE', 0.075], ['MIN_PARAMS_PER_INFLECTION_DAY', 20], ['DAYS_UNTIL_RECOVERY', 15], ['IMMUNITY_MULTIPLIER', 0.5], ['IMMUNITY_MULTIPLIER_US_SUBREGION', 0.3], ['PREV_WEEK_RATIO_SENSITIVITY', 0.75], ['DAYS_UNTIL_LOCKDOWN_FATIGUE', 28], ['MORTALITY_MULTIPLIER', 0.995], ['MORTALITY_MULTIPLIER_US_REOPEN', 0.975], ['MIN_MORTALITY_MULTIPLIER', 0.3], ['MIN_IFR', 0.002], ['DAYS_WITH_IMPORTS', 100], ['USE_UNDETECTED_DEATHS_RATIO', True], ['DEFAULT_REOPEN_SHIFT_DAYS', 15], ['DATE_PARAMS', ['INFLECTION_DAY', 'REOPEN_DATE']], ['RANDOMIZED_PARAMS', ['POST_REOPEN_EQUILIBRIUM_R', 'FALL_R_MULTIPLIER']], ['POTENTIAL_RANDOMIZE_PARAMS', ['RATE_OF_INFLECTION', 'DAILY_IMPORTS']]], 'mean_params': [['INITIAL_R_0', 2.2637755302375644], ['LOCKDOWN_R_0', 0.9038440070216232], ['INFLECTION_DAY', '2020-03-15'], ['RATE_OF_INFLECTION', 0.35245146707754205], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1089.8993483065829], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-10'], ['REOPEN_SHIFT_DAYS', -0.1425555065958532], ['REOPEN_R', 1.2681889965435804], ['REOPEN_INFLECTION', 0.32847835689143956], ['POST_REOPEN_EQUILIBRIUM_R', 1.0073471671122585], ['FALL_R_MULTIPLIER', 1.0020627766084023]], 'median_params': [['INITIAL_R_0', 2.2], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-16'], ['RATE_OF_INFLECTION', 0.3493758807155695], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1049.0], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-13'], ['REOPEN_SHIFT_DAYS', 0.0], ['REOPEN_R', 1.2500000000000002], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 1.0097900527702364], ['FALL_R_MULTIPLIER', 1.002108328865356]], 'num_params': 9072, 'num_params_filt': 684, 'population': 331814684, 'projection_end_date': '2020-11-01', 'region': 'ALL', 'subregion': '', 'top10_params': [['INITIAL_R_0', 2.3200000000000007], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-14'], ['RATE_OF_INFLECTION', 0.35734814824111294], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1203.8], ['MORTALITY_RATE', 0.010000000000000002], ['REOPEN_DATE', '2020-05-06'], ['REOPEN_SHIFT_DAYS', 2.5], ['REOPEN_R', 1.2850000000000001], ['REOPEN_INFLECTION', 0.33499999999999996], ['POST_REOPEN_EQUILIBRIUM_R', 1.0030626817207222], ['FALL_R_MULTIPLIER', 1.002202543680243]], 'top_params': [['INITIAL_R_0', 2.4000000000000004], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-13'], ['RATE_OF_INFLECTION', 0.40837680600799475], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1197], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-01'], ['REOPEN_SHIFT_DAYS', 5], ['REOPEN_R', 1.3000000000000003], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 0.9874301179968146], ['FALL_R_MULTIPLIER', 1.002399465808581]]}
#
#
# ---------------------------------------
# Overwriting params from command line...
# Setting INITIAL_R_0 to: 1.6000000000000005
# -------------------------------------
# End of simulation       : 2020-11-01
# Total infections        : 19,783,218
# Peak hospital beds used : 43,660
# Total deaths            : 50,537
# Loading params file: best_params/latest/US_ALL.json
#
#
#  Best parameters:
#  {'country': 'US', 'current_r': 1.047559981113069, 'date': '2020-10-04', 'first_date': '2020-02-05', 'fixed_params': [['PROJECTION_END_DATE', '2020-11-01'], ['INCUBATION_DAYS', 2], ['INFECTIOUS_DAYS_ARR', [0.5, 1.0, 2.0, 3.0, 2.0, 1.0, 0.5]], ['DEATHS_DAYS_ARR', [1, 2, 3, 4, 4, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2]], ['DAYS_UNTIL_HOSPITALIZATION', 12], ['HOSPITALIZATION_RATE', 0.02], ['DAYS_IN_HOSPITAL', 11], ['DAYS_BEFORE_DEATH', 22], ['DEATH_REPORTING_LAG_ARR', [0.0, 16.5, 13.200000000000001, 10.560000000000002, 8.448000000000002, 6.758400000000001, 5.406720000000002, 4.325376000000001, 3.460300800000001, 2.7682406400000015, 2.214592512000001, 2.103862886400001, 1.9986697420800008, 1.8987362549760005, 1.8037994422272006, 1.7136094701158404, 1.6279289966100483, 1.5465325467795457, 1.4692059194405684, 1.39574562346854, 1.3259583422951131, 1.2596604251803571, 1.1966774039213395, 1.1368435337252722, 1.0800013570390086, 1.026001289187058, 0.9747012247277052, 0.9259661634913199, 0.8796678553167538, 0.8356844625509161, 0.7939002394233703]], ['MEAN_ERROR_DECAY', 1], ['MEAN_ERROR_DECAY_LOWER', 0.95], ['MIN_ALPHA_RATIO', 0.1], ['LOSS_FUNCTION_NAME', 'nth_power_diff'], ['NTH_POWER_ERROR', 2], ['MODEL_WEIGHT_ERROR_POWER', 1.5], ['PERC_PARAMS_PER_INFECTION_DAY', 0.075], ['PERC_PARAMS_PER_INFECTION_DAY_US_EUROPE', 0.075], ['MIN_PARAMS_PER_INFLECTION_DAY', 20], ['DAYS_UNTIL_RECOVERY', 15], ['IMMUNITY_MULTIPLIER', 0.5], ['IMMUNITY_MULTIPLIER_US_SUBREGION', 0.3], ['PREV_WEEK_RATIO_SENSITIVITY', 0.75], ['DAYS_UNTIL_LOCKDOWN_FATIGUE', 28], ['MORTALITY_MULTIPLIER', 0.995], ['MORTALITY_MULTIPLIER_US_REOPEN', 0.975], ['MIN_MORTALITY_MULTIPLIER', 0.3], ['MIN_IFR', 0.002], ['DAYS_WITH_IMPORTS', 100], ['USE_UNDETECTED_DEATHS_RATIO', True], ['DEFAULT_REOPEN_SHIFT_DAYS', 15], ['DATE_PARAMS', ['INFLECTION_DAY', 'REOPEN_DATE']], ['RANDOMIZED_PARAMS', ['POST_REOPEN_EQUILIBRIUM_R', 'FALL_R_MULTIPLIER']], ['POTENTIAL_RANDOMIZE_PARAMS', ['RATE_OF_INFLECTION', 'DAILY_IMPORTS']]], 'mean_params': [['INITIAL_R_0', 2.2637755302375644], ['LOCKDOWN_R_0', 0.9038440070216232], ['INFLECTION_DAY', '2020-03-15'], ['RATE_OF_INFLECTION', 0.35245146707754205], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1089.8993483065829], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-10'], ['REOPEN_SHIFT_DAYS', -0.1425555065958532], ['REOPEN_R', 1.2681889965435804], ['REOPEN_INFLECTION', 0.32847835689143956], ['POST_REOPEN_EQUILIBRIUM_R', 1.0073471671122585], ['FALL_R_MULTIPLIER', 1.0020627766084023]], 'median_params': [['INITIAL_R_0', 2.2], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-16'], ['RATE_OF_INFLECTION', 0.3493758807155695], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1049.0], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-13'], ['REOPEN_SHIFT_DAYS', 0.0], ['REOPEN_R', 1.2500000000000002], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 1.0097900527702364], ['FALL_R_MULTIPLIER', 1.002108328865356]], 'num_params': 9072, 'num_params_filt': 684, 'population': 331814684, 'projection_end_date': '2020-11-01', 'region': 'ALL', 'subregion': '', 'top10_params': [['INITIAL_R_0', 2.3200000000000007], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-14'], ['RATE_OF_INFLECTION', 0.35734814824111294], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1203.8], ['MORTALITY_RATE', 0.010000000000000002], ['REOPEN_DATE', '2020-05-06'], ['REOPEN_SHIFT_DAYS', 2.5], ['REOPEN_R', 1.2850000000000001], ['REOPEN_INFLECTION', 0.33499999999999996], ['POST_REOPEN_EQUILIBRIUM_R', 1.0030626817207222], ['FALL_R_MULTIPLIER', 1.002202543680243]], 'top_params': [['INITIAL_R_0', 2.4000000000000004], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-13'], ['RATE_OF_INFLECTION', 0.40837680600799475], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1197], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-01'], ['REOPEN_SHIFT_DAYS', 5], ['REOPEN_R', 1.3000000000000003], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 0.9874301179968146], ['FALL_R_MULTIPLIER', 1.002399465808581]]}
#
#
# ---------------------------------------
# Overwriting params from command line...
# Setting INITIAL_R_0 to: 1.8000000000000003
# -------------------------------------
# End of simulation       : 2020-11-01
# Total infections        : 30,698,737
# Peak hospital beds used : 61,167
# Total deaths            : 84,475
# Loading params file: best_params/latest/US_ALL.json
#
#
#  Best parameters:
#  {'country': 'US', 'current_r': 1.047559981113069, 'date': '2020-10-04', 'first_date': '2020-02-05', 'fixed_params': [['PROJECTION_END_DATE', '2020-11-01'], ['INCUBATION_DAYS', 2], ['INFECTIOUS_DAYS_ARR', [0.5, 1.0, 2.0, 3.0, 2.0, 1.0, 0.5]], ['DEATHS_DAYS_ARR', [1, 2, 3, 4, 4, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2]], ['DAYS_UNTIL_HOSPITALIZATION', 12], ['HOSPITALIZATION_RATE', 0.02], ['DAYS_IN_HOSPITAL', 11], ['DAYS_BEFORE_DEATH', 22], ['DEATH_REPORTING_LAG_ARR', [0.0, 16.5, 13.200000000000001, 10.560000000000002, 8.448000000000002, 6.758400000000001, 5.406720000000002, 4.325376000000001, 3.460300800000001, 2.7682406400000015, 2.214592512000001, 2.103862886400001, 1.9986697420800008, 1.8987362549760005, 1.8037994422272006, 1.7136094701158404, 1.6279289966100483, 1.5465325467795457, 1.4692059194405684, 1.39574562346854, 1.3259583422951131, 1.2596604251803571, 1.1966774039213395, 1.1368435337252722, 1.0800013570390086, 1.026001289187058, 0.9747012247277052, 0.9259661634913199, 0.8796678553167538, 0.8356844625509161, 0.7939002394233703]], ['MEAN_ERROR_DECAY', 1], ['MEAN_ERROR_DECAY_LOWER', 0.95], ['MIN_ALPHA_RATIO', 0.1], ['LOSS_FUNCTION_NAME', 'nth_power_diff'], ['NTH_POWER_ERROR', 2], ['MODEL_WEIGHT_ERROR_POWER', 1.5], ['PERC_PARAMS_PER_INFECTION_DAY', 0.075], ['PERC_PARAMS_PER_INFECTION_DAY_US_EUROPE', 0.075], ['MIN_PARAMS_PER_INFLECTION_DAY', 20], ['DAYS_UNTIL_RECOVERY', 15], ['IMMUNITY_MULTIPLIER', 0.5], ['IMMUNITY_MULTIPLIER_US_SUBREGION', 0.3], ['PREV_WEEK_RATIO_SENSITIVITY', 0.75], ['DAYS_UNTIL_LOCKDOWN_FATIGUE', 28], ['MORTALITY_MULTIPLIER', 0.995], ['MORTALITY_MULTIPLIER_US_REOPEN', 0.975], ['MIN_MORTALITY_MULTIPLIER', 0.3], ['MIN_IFR', 0.002], ['DAYS_WITH_IMPORTS', 100], ['USE_UNDETECTED_DEATHS_RATIO', True], ['DEFAULT_REOPEN_SHIFT_DAYS', 15], ['DATE_PARAMS', ['INFLECTION_DAY', 'REOPEN_DATE']], ['RANDOMIZED_PARAMS', ['POST_REOPEN_EQUILIBRIUM_R', 'FALL_R_MULTIPLIER']], ['POTENTIAL_RANDOMIZE_PARAMS', ['RATE_OF_INFLECTION', 'DAILY_IMPORTS']]], 'mean_params': [['INITIAL_R_0', 2.2637755302375644], ['LOCKDOWN_R_0', 0.9038440070216232], ['INFLECTION_DAY', '2020-03-15'], ['RATE_OF_INFLECTION', 0.35245146707754205], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1089.8993483065829], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-10'], ['REOPEN_SHIFT_DAYS', -0.1425555065958532], ['REOPEN_R', 1.2681889965435804], ['REOPEN_INFLECTION', 0.32847835689143956], ['POST_REOPEN_EQUILIBRIUM_R', 1.0073471671122585], ['FALL_R_MULTIPLIER', 1.0020627766084023]], 'median_params': [['INITIAL_R_0', 2.2], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-16'], ['RATE_OF_INFLECTION', 0.3493758807155695], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1049.0], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-13'], ['REOPEN_SHIFT_DAYS', 0.0], ['REOPEN_R', 1.2500000000000002], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 1.0097900527702364], ['FALL_R_MULTIPLIER', 1.002108328865356]], 'num_params': 9072, 'num_params_filt': 684, 'population': 331814684, 'projection_end_date': '2020-11-01', 'region': 'ALL', 'subregion': '', 'top10_params': [['INITIAL_R_0', 2.3200000000000007], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-14'], ['RATE_OF_INFLECTION', 0.35734814824111294], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1203.8], ['MORTALITY_RATE', 0.010000000000000002], ['REOPEN_DATE', '2020-05-06'], ['REOPEN_SHIFT_DAYS', 2.5], ['REOPEN_R', 1.2850000000000001], ['REOPEN_INFLECTION', 0.33499999999999996], ['POST_REOPEN_EQUILIBRIUM_R', 1.0030626817207222], ['FALL_R_MULTIPLIER', 1.002202543680243]], 'top_params': [['INITIAL_R_0', 2.4000000000000004], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-13'], ['RATE_OF_INFLECTION', 0.40837680600799475], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1197], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-01'], ['REOPEN_SHIFT_DAYS', 5], ['REOPEN_R', 1.3000000000000003], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 0.9874301179968146], ['FALL_R_MULTIPLIER', 1.002399465808581]]}
#
#
# ---------------------------------------
# Overwriting params from command line...
# Setting INITIAL_R_0 to: 2.0000000000000004
# -------------------------------------
# End of simulation       : 2020-11-01
# Total infections        : 43,966,516
# Peak hospital beds used : 73,625
# Total deaths            : 134,241
# Loading params file: best_params/latest/US_ALL.json
#
#
#  Best parameters:
#  {'country': 'US', 'current_r': 1.047559981113069, 'date': '2020-10-04', 'first_date': '2020-02-05', 'fixed_params': [['PROJECTION_END_DATE', '2020-11-01'], ['INCUBATION_DAYS', 2], ['INFECTIOUS_DAYS_ARR', [0.5, 1.0, 2.0, 3.0, 2.0, 1.0, 0.5]], ['DEATHS_DAYS_ARR', [1, 2, 3, 4, 4, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2]], ['DAYS_UNTIL_HOSPITALIZATION', 12], ['HOSPITALIZATION_RATE', 0.02], ['DAYS_IN_HOSPITAL', 11], ['DAYS_BEFORE_DEATH', 22], ['DEATH_REPORTING_LAG_ARR', [0.0, 16.5, 13.200000000000001, 10.560000000000002, 8.448000000000002, 6.758400000000001, 5.406720000000002, 4.325376000000001, 3.460300800000001, 2.7682406400000015, 2.214592512000001, 2.103862886400001, 1.9986697420800008, 1.8987362549760005, 1.8037994422272006, 1.7136094701158404, 1.6279289966100483, 1.5465325467795457, 1.4692059194405684, 1.39574562346854, 1.3259583422951131, 1.2596604251803571, 1.1966774039213395, 1.1368435337252722, 1.0800013570390086, 1.026001289187058, 0.9747012247277052, 0.9259661634913199, 0.8796678553167538, 0.8356844625509161, 0.7939002394233703]], ['MEAN_ERROR_DECAY', 1], ['MEAN_ERROR_DECAY_LOWER', 0.95], ['MIN_ALPHA_RATIO', 0.1], ['LOSS_FUNCTION_NAME', 'nth_power_diff'], ['NTH_POWER_ERROR', 2], ['MODEL_WEIGHT_ERROR_POWER', 1.5], ['PERC_PARAMS_PER_INFECTION_DAY', 0.075], ['PERC_PARAMS_PER_INFECTION_DAY_US_EUROPE', 0.075], ['MIN_PARAMS_PER_INFLECTION_DAY', 20], ['DAYS_UNTIL_RECOVERY', 15], ['IMMUNITY_MULTIPLIER', 0.5], ['IMMUNITY_MULTIPLIER_US_SUBREGION', 0.3], ['PREV_WEEK_RATIO_SENSITIVITY', 0.75], ['DAYS_UNTIL_LOCKDOWN_FATIGUE', 28], ['MORTALITY_MULTIPLIER', 0.995], ['MORTALITY_MULTIPLIER_US_REOPEN', 0.975], ['MIN_MORTALITY_MULTIPLIER', 0.3], ['MIN_IFR', 0.002], ['DAYS_WITH_IMPORTS', 100], ['USE_UNDETECTED_DEATHS_RATIO', True], ['DEFAULT_REOPEN_SHIFT_DAYS', 15], ['DATE_PARAMS', ['INFLECTION_DAY', 'REOPEN_DATE']], ['RANDOMIZED_PARAMS', ['POST_REOPEN_EQUILIBRIUM_R', 'FALL_R_MULTIPLIER']], ['POTENTIAL_RANDOMIZE_PARAMS', ['RATE_OF_INFLECTION', 'DAILY_IMPORTS']]], 'mean_params': [['INITIAL_R_0', 2.2637755302375644], ['LOCKDOWN_R_0', 0.9038440070216232], ['INFLECTION_DAY', '2020-03-15'], ['RATE_OF_INFLECTION', 0.35245146707754205], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1089.8993483065829], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-10'], ['REOPEN_SHIFT_DAYS', -0.1425555065958532], ['REOPEN_R', 1.2681889965435804], ['REOPEN_INFLECTION', 0.32847835689143956], ['POST_REOPEN_EQUILIBRIUM_R', 1.0073471671122585], ['FALL_R_MULTIPLIER', 1.0020627766084023]], 'median_params': [['INITIAL_R_0', 2.2], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-16'], ['RATE_OF_INFLECTION', 0.3493758807155695], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1049.0], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-13'], ['REOPEN_SHIFT_DAYS', 0.0], ['REOPEN_R', 1.2500000000000002], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 1.0097900527702364], ['FALL_R_MULTIPLIER', 1.002108328865356]], 'num_params': 9072, 'num_params_filt': 684, 'population': 331814684, 'projection_end_date': '2020-11-01', 'region': 'ALL', 'subregion': '', 'top10_params': [['INITIAL_R_0', 2.3200000000000007], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-14'], ['RATE_OF_INFLECTION', 0.35734814824111294], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1203.8], ['MORTALITY_RATE', 0.010000000000000002], ['REOPEN_DATE', '2020-05-06'], ['REOPEN_SHIFT_DAYS', 2.5], ['REOPEN_R', 1.2850000000000001], ['REOPEN_INFLECTION', 0.33499999999999996], ['POST_REOPEN_EQUILIBRIUM_R', 1.0030626817207222], ['FALL_R_MULTIPLIER', 1.002202543680243]], 'top_params': [['INITIAL_R_0', 2.4000000000000004], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-13'], ['RATE_OF_INFLECTION', 0.40837680600799475], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1197], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-01'], ['REOPEN_SHIFT_DAYS', 5], ['REOPEN_R', 1.3000000000000003], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 0.9874301179968146], ['FALL_R_MULTIPLIER', 1.002399465808581]]}
#
#
# ---------------------------------------
# Overwriting params from command line...
# Setting INITIAL_R_0 to: 2.2000000000000006
# -------------------------------------
# End of simulation       : 2020-11-01
# Total infections        : 57,444,105
# Peak hospital beds used : 73,113
# Total deaths            : 200,068
# Loading params file: best_params/latest/US_ALL.json
#
#
#  Best parameters:
#  {'country': 'US', 'current_r': 1.047559981113069, 'date': '2020-10-04', 'first_date': '2020-02-05', 'fixed_params': [['PROJECTION_END_DATE', '2020-11-01'], ['INCUBATION_DAYS', 2], ['INFECTIOUS_DAYS_ARR', [0.5, 1.0, 2.0, 3.0, 2.0, 1.0, 0.5]], ['DEATHS_DAYS_ARR', [1, 2, 3, 4, 4, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2]], ['DAYS_UNTIL_HOSPITALIZATION', 12], ['HOSPITALIZATION_RATE', 0.02], ['DAYS_IN_HOSPITAL', 11], ['DAYS_BEFORE_DEATH', 22], ['DEATH_REPORTING_LAG_ARR', [0.0, 16.5, 13.200000000000001, 10.560000000000002, 8.448000000000002, 6.758400000000001, 5.406720000000002, 4.325376000000001, 3.460300800000001, 2.7682406400000015, 2.214592512000001, 2.103862886400001, 1.9986697420800008, 1.8987362549760005, 1.8037994422272006, 1.7136094701158404, 1.6279289966100483, 1.5465325467795457, 1.4692059194405684, 1.39574562346854, 1.3259583422951131, 1.2596604251803571, 1.1966774039213395, 1.1368435337252722, 1.0800013570390086, 1.026001289187058, 0.9747012247277052, 0.9259661634913199, 0.8796678553167538, 0.8356844625509161, 0.7939002394233703]], ['MEAN_ERROR_DECAY', 1], ['MEAN_ERROR_DECAY_LOWER', 0.95], ['MIN_ALPHA_RATIO', 0.1], ['LOSS_FUNCTION_NAME', 'nth_power_diff'], ['NTH_POWER_ERROR', 2], ['MODEL_WEIGHT_ERROR_POWER', 1.5], ['PERC_PARAMS_PER_INFECTION_DAY', 0.075], ['PERC_PARAMS_PER_INFECTION_DAY_US_EUROPE', 0.075], ['MIN_PARAMS_PER_INFLECTION_DAY', 20], ['DAYS_UNTIL_RECOVERY', 15], ['IMMUNITY_MULTIPLIER', 0.5], ['IMMUNITY_MULTIPLIER_US_SUBREGION', 0.3], ['PREV_WEEK_RATIO_SENSITIVITY', 0.75], ['DAYS_UNTIL_LOCKDOWN_FATIGUE', 28], ['MORTALITY_MULTIPLIER', 0.995], ['MORTALITY_MULTIPLIER_US_REOPEN', 0.975], ['MIN_MORTALITY_MULTIPLIER', 0.3], ['MIN_IFR', 0.002], ['DAYS_WITH_IMPORTS', 100], ['USE_UNDETECTED_DEATHS_RATIO', True], ['DEFAULT_REOPEN_SHIFT_DAYS', 15], ['DATE_PARAMS', ['INFLECTION_DAY', 'REOPEN_DATE']], ['RANDOMIZED_PARAMS', ['POST_REOPEN_EQUILIBRIUM_R', 'FALL_R_MULTIPLIER']], ['POTENTIAL_RANDOMIZE_PARAMS', ['RATE_OF_INFLECTION', 'DAILY_IMPORTS']]], 'mean_params': [['INITIAL_R_0', 2.2637755302375644], ['LOCKDOWN_R_0', 0.9038440070216232], ['INFLECTION_DAY', '2020-03-15'], ['RATE_OF_INFLECTION', 0.35245146707754205], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1089.8993483065829], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-10'], ['REOPEN_SHIFT_DAYS', -0.1425555065958532], ['REOPEN_R', 1.2681889965435804], ['REOPEN_INFLECTION', 0.32847835689143956], ['POST_REOPEN_EQUILIBRIUM_R', 1.0073471671122585], ['FALL_R_MULTIPLIER', 1.0020627766084023]], 'median_params': [['INITIAL_R_0', 2.2], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-16'], ['RATE_OF_INFLECTION', 0.3493758807155695], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1049.0], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-13'], ['REOPEN_SHIFT_DAYS', 0.0], ['REOPEN_R', 1.2500000000000002], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 1.0097900527702364], ['FALL_R_MULTIPLIER', 1.002108328865356]], 'num_params': 9072, 'num_params_filt': 684, 'population': 331814684, 'projection_end_date': '2020-11-01', 'region': 'ALL', 'subregion': '', 'top10_params': [['INITIAL_R_0', 2.3200000000000007], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-14'], ['RATE_OF_INFLECTION', 0.35734814824111294], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1203.8], ['MORTALITY_RATE', 0.010000000000000002], ['REOPEN_DATE', '2020-05-06'], ['REOPEN_SHIFT_DAYS', 2.5], ['REOPEN_R', 1.2850000000000001], ['REOPEN_INFLECTION', 0.33499999999999996], ['POST_REOPEN_EQUILIBRIUM_R', 1.0030626817207222], ['FALL_R_MULTIPLIER', 1.002202543680243]], 'top_params': [['INITIAL_R_0', 2.4000000000000004], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-13'], ['RATE_OF_INFLECTION', 0.40837680600799475], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1197], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-01'], ['REOPEN_SHIFT_DAYS', 5], ['REOPEN_R', 1.3000000000000003], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 0.9874301179968146], ['FALL_R_MULTIPLIER', 1.002399465808581]]}
#
#
# ---------------------------------------
# Overwriting params from command line...
# Setting INITIAL_R_0 to: 2.400000000000001
# -------------------------------------
# ...
#
#
# ---------------------------------------
# Overwriting params from command line...
# Setting RATE_OF_INFLECTION to: 0.55
# -------------------------------------
# End of simulation       : 2020-11-01
# Total infections        : 59,418,209
# Peak hospital beds used : 75,244
# Total deaths            : 215,176
# Loading params file: best_params/latest/US_ALL.json
#
#
#  Best parameters:
#  {'country': 'US', 'current_r': 1.047559981113069, 'date': '2020-10-04', 'first_date': '2020-02-05', 'fixed_params': [['PROJECTION_END_DATE', '2020-11-01'], ['INCUBATION_DAYS', 2], ['INFECTIOUS_DAYS_ARR', [0.5, 1.0, 2.0, 3.0, 2.0, 1.0, 0.5]], ['DEATHS_DAYS_ARR', [1, 2, 3, 4, 4, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2]], ['DAYS_UNTIL_HOSPITALIZATION', 12], ['HOSPITALIZATION_RATE', 0.02], ['DAYS_IN_HOSPITAL', 11], ['DAYS_BEFORE_DEATH', 22], ['DEATH_REPORTING_LAG_ARR', [0.0, 16.5, 13.200000000000001, 10.560000000000002, 8.448000000000002, 6.758400000000001, 5.406720000000002, 4.325376000000001, 3.460300800000001, 2.7682406400000015, 2.214592512000001, 2.103862886400001, 1.9986697420800008, 1.8987362549760005, 1.8037994422272006, 1.7136094701158404, 1.6279289966100483, 1.5465325467795457, 1.4692059194405684, 1.39574562346854, 1.3259583422951131, 1.2596604251803571, 1.1966774039213395, 1.1368435337252722, 1.0800013570390086, 1.026001289187058, 0.9747012247277052, 0.9259661634913199, 0.8796678553167538, 0.8356844625509161, 0.7939002394233703]], ['MEAN_ERROR_DECAY', 1], ['MEAN_ERROR_DECAY_LOWER', 0.95], ['MIN_ALPHA_RATIO', 0.1], ['LOSS_FUNCTION_NAME', 'nth_power_diff'], ['NTH_POWER_ERROR', 2], ['MODEL_WEIGHT_ERROR_POWER', 1.5], ['PERC_PARAMS_PER_INFECTION_DAY', 0.075], ['PERC_PARAMS_PER_INFECTION_DAY_US_EUROPE', 0.075], ['MIN_PARAMS_PER_INFLECTION_DAY', 20], ['DAYS_UNTIL_RECOVERY', 15], ['IMMUNITY_MULTIPLIER', 0.5], ['IMMUNITY_MULTIPLIER_US_SUBREGION', 0.3], ['PREV_WEEK_RATIO_SENSITIVITY', 0.75], ['DAYS_UNTIL_LOCKDOWN_FATIGUE', 28], ['MORTALITY_MULTIPLIER', 0.995], ['MORTALITY_MULTIPLIER_US_REOPEN', 0.975], ['MIN_MORTALITY_MULTIPLIER', 0.3], ['MIN_IFR', 0.002], ['DAYS_WITH_IMPORTS', 100], ['USE_UNDETECTED_DEATHS_RATIO', True], ['DEFAULT_REOPEN_SHIFT_DAYS', 15], ['DATE_PARAMS', ['INFLECTION_DAY', 'REOPEN_DATE']], ['RANDOMIZED_PARAMS', ['POST_REOPEN_EQUILIBRIUM_R', 'FALL_R_MULTIPLIER']], ['POTENTIAL_RANDOMIZE_PARAMS', ['RATE_OF_INFLECTION', 'DAILY_IMPORTS']]], 'mean_params': [['INITIAL_R_0', 2.2637755302375644], ['LOCKDOWN_R_0', 0.9038440070216232], ['INFLECTION_DAY', '2020-03-15'], ['RATE_OF_INFLECTION', 0.35245146707754205], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1089.8993483065829], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-10'], ['REOPEN_SHIFT_DAYS', -0.1425555065958532], ['REOPEN_R', 1.2681889965435804], ['REOPEN_INFLECTION', 0.32847835689143956], ['POST_REOPEN_EQUILIBRIUM_R', 1.0073471671122585], ['FALL_R_MULTIPLIER', 1.0020627766084023]], 'median_params': [['INITIAL_R_0', 2.2], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-16'], ['RATE_OF_INFLECTION', 0.3493758807155695], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1049.0], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-13'], ['REOPEN_SHIFT_DAYS', 0.0], ['REOPEN_R', 1.2500000000000002], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 1.0097900527702364], ['FALL_R_MULTIPLIER', 1.002108328865356]], 'num_params': 9072, 'num_params_filt': 684, 'population': 331814684, 'projection_end_date': '2020-11-01', 'region': 'ALL', 'subregion': '', 'top10_params': [['INITIAL_R_0', 2.3200000000000007], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-14'], ['RATE_OF_INFLECTION', 0.35734814824111294], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1203.8], ['MORTALITY_RATE', 0.010000000000000002], ['REOPEN_DATE', '2020-05-06'], ['REOPEN_SHIFT_DAYS', 2.5], ['REOPEN_R', 1.2850000000000001], ['REOPEN_INFLECTION', 0.33499999999999996], ['POST_REOPEN_EQUILIBRIUM_R', 1.0030626817207222], ['FALL_R_MULTIPLIER', 1.002202543680243]], 'top_params': [['INITIAL_R_0', 2.4000000000000004], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-13'], ['RATE_OF_INFLECTION', 0.40837680600799475], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1197], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-01'], ['REOPEN_SHIFT_DAYS', 5], ['REOPEN_R', 1.3000000000000003], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 0.9874301179968146], ['FALL_R_MULTIPLIER', 1.002399465808581]]}
#
#
# ---------------------------------------
# Overwriting params from command line...
# Setting RATE_OF_INFLECTION to: 0.65
# -------------------------------------
# End of simulation       : 2020-11-01
# Total infections        : 58,878,112
# Peak hospital beds used : 74,081
# Total deaths            : 212,679
# Loading params file: best_params/latest/US_ALL.json
#
#
#  Best parameters:
#  {'country': 'US', 'current_r': 1.047559981113069, 'date': '2020-10-04', 'first_date': '2020-02-05', 'fixed_params': [['PROJECTION_END_DATE', '2020-11-01'], ['INCUBATION_DAYS', 2], ['INFECTIOUS_DAYS_ARR', [0.5, 1.0, 2.0, 3.0, 2.0, 1.0, 0.5]], ['DEATHS_DAYS_ARR', [1, 2, 3, 4, 4, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2]], ['DAYS_UNTIL_HOSPITALIZATION', 12], ['HOSPITALIZATION_RATE', 0.02], ['DAYS_IN_HOSPITAL', 11], ['DAYS_BEFORE_DEATH', 22], ['DEATH_REPORTING_LAG_ARR', [0.0, 16.5, 13.200000000000001, 10.560000000000002, 8.448000000000002, 6.758400000000001, 5.406720000000002, 4.325376000000001, 3.460300800000001, 2.7682406400000015, 2.214592512000001, 2.103862886400001, 1.9986697420800008, 1.8987362549760005, 1.8037994422272006, 1.7136094701158404, 1.6279289966100483, 1.5465325467795457, 1.4692059194405684, 1.39574562346854, 1.3259583422951131, 1.2596604251803571, 1.1966774039213395, 1.1368435337252722, 1.0800013570390086, 1.026001289187058, 0.9747012247277052, 0.9259661634913199, 0.8796678553167538, 0.8356844625509161, 0.7939002394233703]], ['MEAN_ERROR_DECAY', 1], ['MEAN_ERROR_DECAY_LOWER', 0.95], ['MIN_ALPHA_RATIO', 0.1], ['LOSS_FUNCTION_NAME', 'nth_power_diff'], ['NTH_POWER_ERROR', 2], ['MODEL_WEIGHT_ERROR_POWER', 1.5], ['PERC_PARAMS_PER_INFECTION_DAY', 0.075], ['PERC_PARAMS_PER_INFECTION_DAY_US_EUROPE', 0.075], ['MIN_PARAMS_PER_INFLECTION_DAY', 20], ['DAYS_UNTIL_RECOVERY', 15], ['IMMUNITY_MULTIPLIER', 0.5], ['IMMUNITY_MULTIPLIER_US_SUBREGION', 0.3], ['PREV_WEEK_RATIO_SENSITIVITY', 0.75], ['DAYS_UNTIL_LOCKDOWN_FATIGUE', 28], ['MORTALITY_MULTIPLIER', 0.995], ['MORTALITY_MULTIPLIER_US_REOPEN', 0.975], ['MIN_MORTALITY_MULTIPLIER', 0.3], ['MIN_IFR', 0.002], ['DAYS_WITH_IMPORTS', 100], ['USE_UNDETECTED_DEATHS_RATIO', True], ['DEFAULT_REOPEN_SHIFT_DAYS', 15], ['DATE_PARAMS', ['INFLECTION_DAY', 'REOPEN_DATE']], ['RANDOMIZED_PARAMS', ['POST_REOPEN_EQUILIBRIUM_R', 'FALL_R_MULTIPLIER']], ['POTENTIAL_RANDOMIZE_PARAMS', ['RATE_OF_INFLECTION', 'DAILY_IMPORTS']]], 'mean_params': [['INITIAL_R_0', 2.2637755302375644], ['LOCKDOWN_R_0', 0.9038440070216232], ['INFLECTION_DAY', '2020-03-15'], ['RATE_OF_INFLECTION', 0.35245146707754205], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1089.8993483065829], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-10'], ['REOPEN_SHIFT_DAYS', -0.1425555065958532], ['REOPEN_R', 1.2681889965435804], ['REOPEN_INFLECTION', 0.32847835689143956], ['POST_REOPEN_EQUILIBRIUM_R', 1.0073471671122585], ['FALL_R_MULTIPLIER', 1.0020627766084023]], 'median_params': [['INITIAL_R_0', 2.2], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-16'], ['RATE_OF_INFLECTION', 0.3493758807155695], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1049.0], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-13'], ['REOPEN_SHIFT_DAYS', 0.0], ['REOPEN_R', 1.2500000000000002], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 1.0097900527702364], ['FALL_R_MULTIPLIER', 1.002108328865356]], 'num_params': 9072, 'num_params_filt': 684, 'population': 331814684, 'projection_end_date': '2020-11-01', 'region': 'ALL', 'subregion': '', 'top10_params': [['INITIAL_R_0', 2.3200000000000007], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-14'], ['RATE_OF_INFLECTION', 0.35734814824111294], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1203.8], ['MORTALITY_RATE', 0.010000000000000002], ['REOPEN_DATE', '2020-05-06'], ['REOPEN_SHIFT_DAYS', 2.5], ['REOPEN_R', 1.2850000000000001], ['REOPEN_INFLECTION', 0.33499999999999996], ['POST_REOPEN_EQUILIBRIUM_R', 1.0030626817207222], ['FALL_R_MULTIPLIER', 1.002202543680243]], 'top_params': [['INITIAL_R_0', 2.4000000000000004], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-13'], ['RATE_OF_INFLECTION', 0.40837680600799475], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1197], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-01'], ['REOPEN_SHIFT_DAYS', 5], ['REOPEN_R', 1.3000000000000003], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 0.9874301179968146], ['FALL_R_MULTIPLIER', 1.002399465808581]]}
#
#
# ---------------------------------------
# Overwriting params from command line...
# Setting RATE_OF_INFLECTION to: 0.5
# -------------------------------------
# End of simulation       : 2020-11-01
# Total infections        : 59,774,649
# Peak hospital beds used : 76,025
# Total deaths            : 216,799
# Loading params file: best_params/latest/US_ALL.json
#
#
#  Best parameters:
#  {'country': 'US', 'current_r': 1.047559981113069, 'date': '2020-10-04', 'first_date': '2020-02-05', 'fixed_params': [['PROJECTION_END_DATE', '2020-11-01'], ['INCUBATION_DAYS', 2], ['INFECTIOUS_DAYS_ARR', [0.5, 1.0, 2.0, 3.0, 2.0, 1.0, 0.5]], ['DEATHS_DAYS_ARR', [1, 2, 3, 4, 4, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2]], ['DAYS_UNTIL_HOSPITALIZATION', 12], ['HOSPITALIZATION_RATE', 0.02], ['DAYS_IN_HOSPITAL', 11], ['DAYS_BEFORE_DEATH', 22], ['DEATH_REPORTING_LAG_ARR', [0.0, 16.5, 13.200000000000001, 10.560000000000002, 8.448000000000002, 6.758400000000001, 5.406720000000002, 4.325376000000001, 3.460300800000001, 2.7682406400000015, 2.214592512000001, 2.103862886400001, 1.9986697420800008, 1.8987362549760005, 1.8037994422272006, 1.7136094701158404, 1.6279289966100483, 1.5465325467795457, 1.4692059194405684, 1.39574562346854, 1.3259583422951131, 1.2596604251803571, 1.1966774039213395, 1.1368435337252722, 1.0800013570390086, 1.026001289187058, 0.9747012247277052, 0.9259661634913199, 0.8796678553167538, 0.8356844625509161, 0.7939002394233703]], ['MEAN_ERROR_DECAY', 1], ['MEAN_ERROR_DECAY_LOWER', 0.95], ['MIN_ALPHA_RATIO', 0.1], ['LOSS_FUNCTION_NAME', 'nth_power_diff'], ['NTH_POWER_ERROR', 2], ['MODEL_WEIGHT_ERROR_POWER', 1.5], ['PERC_PARAMS_PER_INFECTION_DAY', 0.075], ['PERC_PARAMS_PER_INFECTION_DAY_US_EUROPE', 0.075], ['MIN_PARAMS_PER_INFLECTION_DAY', 20], ['DAYS_UNTIL_RECOVERY', 15], ['IMMUNITY_MULTIPLIER', 0.5], ['IMMUNITY_MULTIPLIER_US_SUBREGION', 0.3], ['PREV_WEEK_RATIO_SENSITIVITY', 0.75], ['DAYS_UNTIL_LOCKDOWN_FATIGUE', 28], ['MORTALITY_MULTIPLIER', 0.995], ['MORTALITY_MULTIPLIER_US_REOPEN', 0.975], ['MIN_MORTALITY_MULTIPLIER', 0.3], ['MIN_IFR', 0.002], ['DAYS_WITH_IMPORTS', 100], ['USE_UNDETECTED_DEATHS_RATIO', True], ['DEFAULT_REOPEN_SHIFT_DAYS', 15], ['DATE_PARAMS', ['INFLECTION_DAY', 'REOPEN_DATE']], ['RANDOMIZED_PARAMS', ['POST_REOPEN_EQUILIBRIUM_R', 'FALL_R_MULTIPLIER']], ['POTENTIAL_RANDOMIZE_PARAMS', ['RATE_OF_INFLECTION', 'DAILY_IMPORTS']]], 'mean_params': [['INITIAL_R_0', 2.2637755302375644], ['LOCKDOWN_R_0', 0.9038440070216232], ['INFLECTION_DAY', '2020-03-15'], ['RATE_OF_INFLECTION', 0.35245146707754205], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1089.8993483065829], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-10'], ['REOPEN_SHIFT_DAYS', -0.1425555065958532], ['REOPEN_R', 1.2681889965435804], ['REOPEN_INFLECTION', 0.32847835689143956], ['POST_REOPEN_EQUILIBRIUM_R', 1.0073471671122585], ['FALL_R_MULTIPLIER', 1.0020627766084023]], 'median_params': [['INITIAL_R_0', 2.2], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-16'], ['RATE_OF_INFLECTION', 0.3493758807155695], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1049.0], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-13'], ['REOPEN_SHIFT_DAYS', 0.0], ['REOPEN_R', 1.2500000000000002], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 1.0097900527702364], ['FALL_R_MULTIPLIER', 1.002108328865356]], 'num_params': 9072, 'num_params_filt': 684, 'population': 331814684, 'projection_end_date': '2020-11-01', 'region': 'ALL', 'subregion': '', 'top10_params': [['INITIAL_R_0', 2.3200000000000007], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-14'], ['RATE_OF_INFLECTION', 0.35734814824111294], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1203.8], ['MORTALITY_RATE', 0.010000000000000002], ['REOPEN_DATE', '2020-05-06'], ['REOPEN_SHIFT_DAYS', 2.5], ['REOPEN_R', 1.2850000000000001], ['REOPEN_INFLECTION', 0.33499999999999996], ['POST_REOPEN_EQUILIBRIUM_R', 1.0030626817207222], ['FALL_R_MULTIPLIER', 1.002202543680243]], 'top_params': [['INITIAL_R_0', 2.4000000000000004], ['LOCKDOWN_R_0', 0.9], ['INFLECTION_DAY', '2020-03-13'], ['RATE_OF_INFLECTION', 0.40837680600799475], ['LOCKDOWN_FATIGUE', 1.0], ['DAILY_IMPORTS', 1197], ['MORTALITY_RATE', 0.01], ['REOPEN_DATE', '2020-05-01'], ['REOPEN_SHIFT_DAYS', 5], ['REOPEN_R', 1.3000000000000003], ['REOPEN_INFLECTION', 0.325], ['POST_REOPEN_EQUILIBRIUM_R', 0.9874301179968146], ['FALL_R_MULTIPLIER', 1.002399465808581]]}
#
#
# ---------------------------------------
# Overwriting params from command line...
# Setting RATE_OF_INFLECTION to: 0.25
# -------------------------------------
# End of simulation       : 2020-11-01
# Total infections        : 63,927,790
# Peak hospital beds used : 85,825
# Total deaths            : 234,666
